# %% [markdown]
# ### first example to inference model

# %%
from huggingface_hub import InferenceClient

# %%
client = InferenceClient()

completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-V3-0324",
    messages=[
        {
            "role": "user",
            "content": "answer me few question. Question 1: what model you are ? and when latest information you can provide to me. Question 2: what is ai agent?"
        }
    ],
)

# %%
print(completion.choices[0].message["content"])
# Out:
# ### Question 1: What model are you? And what is the latest information you can provide to me?
# **Answer:**
# I am **DeepSeek-V3**, an advanced AI language model developed by **DeepSeek**. My knowledge is up-to-date until **July 2024**, and I can access real-time information through **web search** (if enabled by the user). Without web search, my responses are based on my pre-trained knowledge (up to mid-2024).
#
# ### Question 2: What is an AI agent?
# **Answer:**
# An **AI agent** is an artificial intelligence system designed to perform tasks autonomously or semi-autonomously by perceiving its environment, processing information, and taking actions to achieve specific goals.
#
# #### Key Characteristics of AI Agents:
# 1. **Autonomy** – Operates without constant human intervention.
# 2. **Perception** – Uses sensors, data inputs, or APIs to gather information.
# 3. **Decision-Making** – Applies logic, machine learning, or rules to make choices.
# ...

# %% [markdown]
# ### second example to inference model

# %%
import os
import sys
from fpdf import FPDF
import time

home_directory = os.path.expanduser('C:\Program Files\Studying\coding')
package_root = os.path.join(home_directory, 'RAG_project')
sys.path.insert(1,package_root)
os.chdir(sys.path[1])

from src import utils_private

from huggingface_hub import InferenceClient

client = InferenceClient(
    api_key = utils_private.hf_api_key,
    provider = "auto",   # Automatically selects best provider
)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\P'
# <>:6: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jason\AppData\Local\Temp\ipykernel_16228\3389884504.py:6: SyntaxWarning: invalid escape sequence '\P'
#   home_directory = os.path.expanduser('C:\Program Files\Studying\coding')
# c:\Users\jason\miniconda3\envs\ai\Lib\site-packages\fpdf\__init__.py:41: UserWarning: You have both PyFPDF & fpdf2 installed. Both packages cannot be installed at the same time as they share the same module namespace. To only keep fpdf2, run: pip uninstall --yes pypdf && pip install --upgrade fpdf2
#   warnings.warn(

# %%
def save_string_to_pdf(text: str, filename: str = "output.pdf"):
    pdf = FPDF()
    pdf.add_page()
    
    # Use a built-in font + aggressive cleaning of special characters
    pdf.set_font("helvetica", size=12)

    # Clean ALL common problematic Unicode characters
    replacements = {
        '\u2018': "'",   # ‘ left single quote
        '\u2019': "'",   # ’ right single quote
        '\u201C': '"',   # “ left double quote
        '\u201D': '"',   # ” right double quote
        '\u2013': '-',   # – en dash
        '\u2014': '--',  # — em dash
        '\u2026': '...', # … ellipsis
        '\u00A0': ' ',   # non-breaking space
        '\u00AD': '',    # soft hyphen
    }
    
    for old, new in replacements.items():
        text = text.replace(old, new)

    # Extra safety: remove any remaining character that can't fit in latin-1
    text = text.encode('latin-1', errors='replace').decode('latin-1')

    pdf.multi_cell(0, 10, text)
    
    pdf.output(filename)
    print(f"✅ PDF saved successfully: {filename}")

# %%
big_storyline = """
Travel
Superstitious
Hong Kong
American
Movie
Imposter syndrome
conspiracy theories
Morning Routines: How you start the day for success.
Cooking: Signature dishes and "kitchen fails."
Fitness: Yoga, gym, running, or just walking.
Mental Health: Meditation, boundaries, and stress management.
Interior Design: Minimalism vs. maximalism in your home.
Data Science: Big data, ethics, and visualization.
Hardware: Building PCs vs. buying laptops.
Automation: Smart home setups and time-saving scripts.
Virtual Reality: The future of gaming and remote work.
Remote Work: Managing a home office vs. commuting.
Networking: Building genuine professional connections.
Side Hustles: Turning hobbies into small businesses.
Leadership: What makes a great manager?
Public Speaking: Overcoming nerves and giving presentations.
Time Management: Techniques like Pomodoro or Time Blocking.
Career Pivots: Changing industries later in life.
Mentorship: Learning from others vs. teaching.
Work Life Balance: Defining "enough" in a hustle culture.
Education: Self-teaching vs. traditional university.
Brainstorming: Methods for generating new ideas.
Interviewing: Weird questions and preparation tips.
Happiness: What does it actually mean to you?
Friendship: How to maintain bonds as an adult.
Ethics: Tough "What would you do?" scenarios.
Creativity: Where do you get your best ideas?
Astronomy: The scale of the universe and our place in it.
Philosophy: Stoicism, Existentialism, or daily ethics.
Childhood: Toys and games that defined your youth.
Psychology: Why humans behave the way they do.
Community: The importance of local neighborhoods.
Legacy: What do you want to be remembered for?
Conspiracy Theories: The funny ones that hurt nobody.
Life Hacks: Small tricks that save huge time.
Urban Legends: Ghost stories or local myths.
Superpowers: Which one would you choose and why?
Collectibles: Coins, stamps, sneakers, or cards.
DIY Projects: Home repairs or craft builds.
Weather: Why it's the ultimate icebreaker.
Investing: Basics of personal finance and stocks.
Volunteering: Giving back to the community.
Shopping: The psychology of sales and marketing.
AI Ethics: The "right" way to use the tools we're building."""

# %%
crystal_storyline = []
for i in big_storyline.splitlines():
    first_part = i.split(':')[0]
    crystal_storyline.append(first_part)

# %%
for story_line in crystal_storyline:

    # Chat completion
    print('Starting: ',story_line)
    completion = client.chat.completions.create(
        model="deepseek-ai/DeepSeek-V3-0324",
        messages=[{"role": "user", 
                "content": f"""
                
                    I would give you one word and please create a story to me. 

                    here is the requirement:
                    1) at least 5000 words (not characters !!!!!!)
                    2) at least 5 people in the story, and you need to mention they have different personalities, backgrounds, and goals. You can create any characters you want.
                    3) You can add any genres to the story; drama, comedy, action, horror, sci-fi, western, romance, thriller, fantasy, apocalypse, martial arts, and sports. Anything you want, just give more creativity to the story
                    4) The story must have a ending

                    The word is "{story_line}". Just give me the article, paragraph. No need bullet point

                    Remember to check the word count, it must be at least 5000 words. If not, please keep writing until you reach the requirement. 
                    
                    In addition, i dont want to see any * and " in the text.
                    
                    please no need to have a line seperate in a paragraph.

                    Just give me the story, no need to have any explanation or anything else.
    """}]
    )
    print('Finished: ',story_line)
    text = completion.choices[0].message["content"]
    save_string_to_pdf(text = text, filename=f"{story_line}.pdf")
    
    time.sleep(3)
# Out:
# Starting:
# Finished:
# ✅ PDF saved successfully: .pdf
# Starting:  Coffee Or Tea
# Finished:  Coffee Or Tea
# ✅ PDF saved successfully: Coffee Or Tea.pdf
# Starting:  Sustainability
# Finished:  Sustainability
# ✅ PDF saved successfully: Sustainability.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 33
#      30 text = completion.choices[0].message["content"]
#      31 save_string_to_pdf(text = text, filename=f"{story_line}.pdf")
# ---> 33 time.sleep(3)
#
# KeyboardInterrupt:
